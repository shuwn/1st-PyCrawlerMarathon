# %% [markdown]
# # Ettoday 網路爬蟲實作練習
#
#
# * 能夠利用 Request + BeatifulSour 撰寫爬蟲，並存放到合適的資料結構

# %% [markdown]
# ## Ettoday 網頁爬蟲

# %%
import requests
from bs4 import BeautifulSoup

url = 'https://www.ettoday.net/news/news-list.htm'
r = requests.get(url)

soup = BeautifulSoup(r.text, "html5lib")
# print(soup)

# class 是 Python 的保留字，故要搜索 CSS Class 要寫成 class_
for d in soup.find(class_="part_list_2").find_all('h3'):
    # find() 只回傳第一個找到的區塊，而 find_all() 會回傳一個 list, 包含所有符合條件的區塊。
    # 傳入的引數第一個通常是 tag 名稱，第二個引數若未指明屬性就代表 class 名稱，也可以直接使用 id 等屬性去定位區塊。
    # 定位到區塊後，可以取出其屬性與包含的字串值
    # 兩者看起來定義大部分相似，唯一不同時 findAll() 中多了一個參數 limit。
    # 在實際使用中，find () 就相當於 findAll () 中 limit = 1 時的特殊情況。
    # find_all方法，找到所有該標籤，返回一個list，如果只找到一個也是返回list，用[0]提取
    # L[0] 取得第一個、L[1] 取得第二個...，L[-1] 是取出倒數第一個。
    # 這邊是因為 d.find_all('a') 回來的元素只有一個，所以你取第一個跟取倒數第一個內容是一樣的。
    # https://bit.ly/2UfSS4A
    # 因為當時觀察的時候發現該區塊下有可能會有廣告出現，廣告也會用 <a> 的方式存在，有時候會抓到的是廣告的 <a>。
    # 所以，這邊改成抓「最後一個 <a>」，不管有沒有廣告都會抓到正確的。
    print(d.find_all(class_="date")[0].text, d.find_all('a')[0].text)
    # 「關於 find_all() 與  find() 的差異性」在於一個會回傳 HTML 物件，一個會回傳包含 HTML 物件所組成的 List
    # 因此 find('a') 會等同於 find_all('a')[0] 的結果。大部分情況，如果條件下得夠好，可以採用 find 就好
    # 但有些時候條件不好下，只能用某個條件中的第 N 個的規則找到，就非得改用 find_all 再加上位置。
    # 另外 find_all 也會用在資料有規則的情況，例如我們想要抓所有的新聞（每一則新聞的 HTML 是類似的），我們也會採用 find_all。
# Out:
# 2020/03/20 16:06 「疫」拳重擊！2月外銷訂單年減0.8％
# 2020/03/20 16:06 經濟衝擊　中華信評：壽險業獲利與資本水準挑戰更大
# 2020/03/20 16:06 沈政男／新冠全球致死率差很大？致死率怎麼推估
# 2020/03/20 16:05 逐筆交易／台股開收盤、盤中如何交易　新制委託注意事項一秒懂
# 2020/03/20 16:05 蘋果官網新增AR功能！距離不是問題　iPad Pro就在眼前
# 2020/03/20 16:04 無約旅外球員繼續跟中職培訓 　但不能打二軍例行賽
# 2020/03/20 16:03 不斷更新／南韓22日全面篩檢「歐洲入境旅客」　將派2專機赴義大利撤僑！
# 2020/03/20 16:01 台南市性侵被害人一站式服務　黃偉哲率團隊成為被害人有力依靠
# 2020/03/20 16:01 Dyson V8手持吸塵器「變迷你」　重量輕450克
# 2020/03/20 16:00 無印良品專屬自動販賣機正式登場！「黃麻環保購物袋」是亮點單品
# 2020/03/20 15:59 宏達電去年第4季虧損23.7億元　每股稅後淨損2.87元
# 2020/03/20 15:57 網傳「儲備1個月糧食」製造恐慌　新北市一協會負責人遭約談
# 2020/03/20 15:57 預防群聚感染　台東縣府試辦分區及居家辦公併行
# 2020/03/20 15:57 山本富野捐贈復康巴士　嘉惠雲林偏鄉身障兒童
# 2020/03/20 15:56 Facebook網頁「深色模式」來了！用戶可自選模式　版面也有新設計
# 2020/03/20 15:55 「救救台灣留學生！」國民黨籲蔡英文：適度開放家長寄口罩、防疫物資
# 2020/03/20 15:55 5年幫7.1萬浪貓絕育！台灣之心夜貓志工隊配合作息　讓牠們自發性入籠
# 2020/03/20 15:54 口罩給美國不給大陸　陸官媒：民進黨「上貢、做奴才」沒好下場
# 2020/03/20 15:53 快訊／北市中正區驚見「孩童受困車內」！　警消急破窗救援
# 2020/03/20 15:50 台南安平漁港內違規放網採捕　海巡依法函送裁處
# 2020/03/20 15:49 羅明才建議蘇貞昌喊「不罷了」：罷了還不是要重選一次
# ...

# %% [markdown]
# ## 作業目標
#
# 根據範例 ，完成以下問題：
#
# * ① 取出今天所有的發文
# * ② 如果想要依照類別分類，怎麼儲存會比較好？
# * ③ 哪一個類別的文章最多
