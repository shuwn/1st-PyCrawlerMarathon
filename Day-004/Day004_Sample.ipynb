# %% [markdown]
# # 利用 Python 存取 API
#
#
# * 了解 Server Client 的架構與溝通方法
# * 知道 HTTP Request & Response 的內容
# * 什麼是 API？如何用 Python 程式存取 API 資料

# %% [markdown]
# ## 下載檔案

# %%
import requests

r = requests.get('https://api.github.com/events')

# %%
import json

json.loads(r.text)
# Out:
# [{'id': '12645382356',
#   'type': 'CreateEvent',
#   'actor': {'id': 53246430,
#    'login': 'i15232',
#    'display_login': 'i15232',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/i15232',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/53246430?'},
#   'repo': {'id': 272711764,
#    'name': 'i15232/pic24f-hello-world-uart',
#    'url': 'https://api.github.com/repos/i15232/pic24f-hello-world-uart'},
#   'payload': {'ref': 'develop',
#    'ref_type': 'branch',
#    'master_branch': 'develop',
#    'description': 'PIC24F Hello World Example',
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2020-06-16T13:12:39Z'},
#  {'id': '12645382346',
#   'type': 'PushEvent',
#   'actor': {'id': 33628387,
#    'login': 'ninaszymor',
#    'display_login': 'ninaszymor',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/ninaszymor',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/33628387?'},
#   'repo': {'id': 128402194,
#    'name': 'raspberrypilearning/cd-sebento-htmlcss-2',
#    'url': 'https://api.github.com/repos/raspberrypilearning/cd-sebento-htmlcss-2'},
#   'payload': {'push_id': 5237139633,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/l10n_master',
#    'head': '2c554f1004076db0bca6b153d13d96284f319af3',
#    'before': '03d5b89f2c89e5f127e48537a8b95d7d2affa60b',
#    'commits': [{'sha': '2c554f1004076db0bca6b153d13d96284f319af3',
#      'author': {'email': '33628387+ninaszymor@users.noreply.github.com',
#       'name': 'ninaszymor'},
#      'message': 'New translations frontPageIdStyles.png (Portuguese)',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/raspberrypilearning/cd-sebento-htmlcss-2/commits/2c554f1004076db0bca6b153d13d96284f319af3'}]},
#   'public': True,
#   'created_at': '2020-06-16T13:12:39Z',
#   'org': {'id': 6546294,
#    'login': 'raspberrypilearning',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/raspberrypilearning',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/6546294?'}},
#  {'id': '12645382344',
#   'type': 'PushEvent',
#   'actor': {'id': 358882,
#    'login': 'nuclearsandwich',
#    'display_login': 'nuclearsandwich',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/nuclearsandwich',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/358882?'},
#   'repo': {'id': 161254839,
#    'name': 'ros2-gbp/python_qt_binding-release',
#    'url': 'https://api.github.com/repos/ros2-gbp/python_qt_binding-release'},
#   'payload': {'push_id': 5237139635,
#    'size': 2,
#    'distinct_size': 2,
#    'ref': 'refs/heads/upstream',
#    'head': 'be2c664d21ebe8695e678a4c3dceb075f4c68ce7',
#    'before': 'f862f3f367e14474aca587c0555b9b197595d819',
#    'commits': [{'sha': '7046924df500c1b8c10f1e7d48fef0b95c9d388d',
#      'author': {'email': 'steven@nuclearsandwich.com',
#       'name': 'Steven! Ragnarök'},
#      'message': 'Created orphaned branch upstream',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/ros2-gbp/python_qt_binding-release/commits/7046924df500c1b8c10f1e7d48fef0b95c9d388d'},
#     {'sha': 'be2c664d21ebe8695e678a4c3dceb075f4c68ce7',
#      'author': {'email': 'steven@nuclearsandwich.com',
#       'name': 'Steven! Ragnarök'},
#      'message': "Imported upstream version '1.0.5' of 'upstream'",
#      'distinct': True,
#      'url': 'https://api.github.com/repos/ros2-gbp/python_qt_binding-release/commits/be2c664d21ebe8695e678a4c3dceb075f4c68ce7'}]},
#   'public': True,
#   'created_at': '2020-06-16T13:12:39Z',
#   'org': {'id': 29735195,
#    'login': 'ros2-gbp',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/ros2-gbp',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/29735195?'}},
#  {'id': '12645382349',
#   'type': 'CommitCommentEvent',
#   'actor': {'id': 35613825,
#    'login': 'vercel[bot]',
#    'display_login': 'vercel',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/vercel[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/35613825?'},
#   'repo': {'id': 267432625,
#    'name': 'TomAFrench/sablier-safe-app',
#    'url': 'https://api.github.com/repos/TomAFrench/sablier-safe-app'},
#   'payload': {'comment': {'url': 'https://api.github.com/repos/TomAFrench/sablier-safe-app/comments/39943371',
#     'html_url': 'https://github.com/TomAFrench/sablier-safe-app/commit/fe971e2115176d11147ec262f789cced841153b3#commitcomment-39943371',
#     'id': 39943371,
#     'node_id': 'MDEzOkNvbW1pdENvbW1lbnQzOTk0MzM3MQ==',
#     'user': {'login': 'vercel[bot]',
#      'id': 35613825,
#      'node_id': 'MDM6Qm90MzU2MTM4MjU=',
#      'avatar_url': 'https://avatars2.githubusercontent.com/in/8329?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/vercel%5Bbot%5D',
#      'html_url': 'https://github.com/apps/vercel',
#      'followers_url': 'https://api.github.com/users/vercel%5Bbot%5D/followers',
#      'following_url': 'https://api.github.com/users/vercel%5Bbot%5D/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/vercel%5Bbot%5D/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/vercel%5Bbot%5D/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/vercel%5Bbot%5D/subscriptions',
#      'organizations_url': 'https://api.github.com/users/vercel%5Bbot%5D/orgs',
#      'repos_url': 'https://api.github.com/users/vercel%5Bbot%5D/repos',
#      'events_url': 'https://api.github.com/users/vercel%5Bbot%5D/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/vercel%5Bbot%5D/received_events',
#      'type': 'Bot',
#      'site_admin': False},
#     'position': None,
#     'line': None,
#     'path': None,
#     'commit_id': 'fe971e2115176d11147ec262f789cced841153b3',
#     'created_at': '2020-06-16T13:12:39Z',
#     'updated_at': '2020-06-16T13:12:39Z',
#     'author_association': 'NONE',
#     'body': '\nSuccessfully deployed to following URLs:\n\n* https://sablier-safe-app-6gx6jlc5z.vercel.app\n* https://sablier-safe-app.now.sh\n* https://sablier-safe-app.tomafrench.vercel.app\n* https://sablier-safe-app-git-develop.tomafrench.vercel.app\n* https://sablier-safe-app.tomafrench.now.sh\n* https://sablier-safe-app-git-develop.tomafrench.now.sh\n\t'}},
#   'public': True,
#   'created_at': '2020-06-16T13:12:39Z'},
#  {'id': '12645382336',
#   'type': 'PullRequestEvent',
#   'actor': {'id': 49699333,
#    'login': 'dependabot[bot]',
#    'display_login': 'dependabot',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/dependabot[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/49699333?'},
#   'repo': {'id': 272711428,
#    'name': 'vader26/save-nature',
#    'url': 'https://api.github.com/repos/vader26/save-nature'},
#   'payload': {'action': 'opened',
#    'number': 1,
#    'pull_request': {'url': 'https://api.github.com/repos/vader26/save-nature/pulls/1',
#     'id': 435204699,
#     'node_id': 'MDExOlB1bGxSZXF1ZXN0NDM1MjA0Njk5',
#     'html_url': 'https://github.com/vader26/save-nature/pull/1',
#     'diff_url': 'https://github.com/vader26/save-nature/pull/1.diff',
#     'patch_url': 'https://github.com/vader26/save-nature/pull/1.patch',
#     'issue_url': 'https://api.github.com/repos/vader26/save-nature/issues/1',
#     'number': 1,
#     'state': 'open',
#     'locked': False,
#     'title': 'Bump websocket-extensions from 0.1.3 to 0.1.4',
#     'user': {'login': 'dependabot[bot]',
#      'id': 49699333,
#      'node_id': 'MDM6Qm90NDk2OTkzMzM=',
#      'avatar_url': 'https://avatars0.githubusercontent.com/in/29110?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/dependabot%5Bbot%5D',
#      'html_url': 'https://github.com/apps/dependabot',
#      'followers_url': 'https://api.github.com/users/dependabot%5Bbot%5D/followers',
#      'following_url': 'https://api.github.com/users/dependabot%5Bbot%5D/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/dependabot%5Bbot%5D/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/dependabot%5Bbot%5D/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/dependabot%5Bbot%5D/subscriptions',
#      'organizations_url': 'https://api.github.com/users/dependabot%5Bbot%5D/orgs',
#      'repos_url': 'https://api.github.com/users/dependabot%5Bbot%5D/repos',
#      'events_url': 'https://api.github.com/users/dependabot%5Bbot%5D/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/dependabot%5Bbot%5D/received_events',
#      'type': 'Bot',
#      'site_admin': False},
#     'body': 'Bumps [websocket-extensions](https://github.com/faye/websocket-extensions-node) from 0.1.3 to 0.1.4.\n<details>\n<summary>Changelog</summary>\n<p><em>Sourced from <a href="https://github.com/faye/websocket-extensions-node/blob/master/CHANGELOG.md">websocket-extensions\'s changelog</a>.</em></p>\n<blockquote>\n<h3>0.1.4 / 2020-06-02</h3>\n<ul>\n<li>Remove a ReDoS vulnerability in the header parser (CVE-2020-7662, reported by\nRobert McLaughlin)</li>\n<li>Change license from MIT to Apache 2.0</li>\n</ul>\n</blockquote>\n</details>\n<details>\n<summary>Commits</summary>\n<ul>\n<li><a href="https://github.com/faye/websocket-extensions-node/commit/8efd0cd6e35faf9bb9cb08759be1e27082177d43"><code>8efd0cd</code></a> Bump version to 0.1.4</li>\n<li><a href="https://github.com/faye/websocket-extensions-node/commit/3dad4ad44a8c5f74d4f8f4efd3f9d6e0b5df3051"><code>3dad4ad</code></a> Remove ReDoS vulnerability in the Sec-WebSocket-Extensions header parser</li>\n<li><a href="https://github.com/faye/websocket-extensions-node/commit/4a76c75efb1c5d6a2f60550e9501757458d19533"><code>4a76c75</code></a> Add Node versions 13 and 14 on Travis</li>\n<li><a href="https://github.com/faye/websocket-extensions-node/commit/44a677a9c0631daed0b0f4a4b68c095b624183b8"><code>44a677a</code></a> Formatting change: {...} should have spaces inside the braces</li>\n<li><a href="https://github.com/faye/websocket-extensions-node/commit/f6c50aba0c20ff45b0f87cea33babec1217ec3f5"><code>f6c50ab</code></a> Let npm reformat package.json</li>\n<li><a href="https://github.com/faye/websocket-extensions-node/commit/2d211f3705d52d9efb4f01daf5a253adf828592e"><code>2d211f3</code></a> Change markdown formatting of docs.</li>\n<li><a href="https://github.com/faye/websocket-extensions-node/commit/0b620834cc1e1f2eace1d55ab17f71d90d88271d"><code>0b62083</code></a> Update Travis target versions.</li>\n<li><a href="https://github.com/faye/websocket-extensions-node/commit/729a4653073fa8dd020561113513bfa2e2119415"><code>729a465</code></a> Switch license to Apache 2.0.</li>\n<li>See full diff in <a href="https://github.com/faye/websocket-extensions-node/compare/0.1.3...0.1.4">compare view</a></li>\n</ul>\n</details>\n<br />\n\n\n[![Dependabot compatibility score](https://dependabot-badges.githubapp.com/badges/compatibility_score?dependency-name=websocket-extensions&package-manager=npm_and_yarn&previous-version=0.1.3&new-version=0.1.4)](https://help.github.com/articles/configuring-automated-security-fixes)\n\nDependabot will resolve any conflicts with this PR as long as you don\'t alter it yourself. You can also trigger a rebase manually by commenting `@dependabot rebase`.\n\n[//]: # (dependabot-automerge-start)\n[//]: # (dependabot-automerge-end)\n\n---\n\n<details>\n<summary>Dependabot commands and options</summary>\n<br />\n\nYou can trigger Dependabot actions by commenting on this PR:\n- `@dependabot rebase` will rebase this PR\n- `@dependabot recreate` will recreate this PR, overwriting any edits that have been made to it\n- `@dependabot merge` will merge this PR after your CI passes on it\n- `@dependabot squash and merge` will squash and merge this PR after your CI passes on it\n- `@dependabot cancel merge` will cancel a previously requested merge and block automerging\n- `@dependabot reopen` will reopen this PR if it is closed\n- `@dependabot close` will close this PR and stop Dependabot recreating it. You can achieve the same result by closing it manually\n- `@dependabot ignore this major version` will close this PR and stop Dependabot creating any more for this major version (unless you reopen the PR or upgrade to it yourself)\n- `@dependabot ignore this minor version` will close this PR and stop Dependabot creating any more for this minor version (unless you reopen the PR or upgrade to it yourself)\n- `@dependabot ignore this dependency` will close this PR and stop Dependabot creating any more for this dependency (unless you reopen the PR or upgrade to it yourself)\n-  ...
#     'created_at': '2020-06-16T13:12:39Z',
#     'updated_at': '2020-06-16T13:12:39Z',
#     'closed_at': None,
#     'merged_at': None,
#     'merge_commit_sha': None,
#     'assignee': None,
#     'assignees': [],
#     'requested_reviewers': [],
#     'requested_teams': [],
#     'labels': [],
#     'milestone': None,
#     'draft': False,
#     'commits_url': 'https://api.github.com/repos/vader26/save-nature/pulls/1/commits',
#     'review_comments_url': 'https://api.github.com/repos/vader26/save-nature/pulls/1/comments',
#     'review_comment_url': 'https://api.github.com/repos/vader26/save-nature/pulls/comments{/number}',
#     'comments_url': 'https://api.github.com/repos/vader26/save-nature/issues/1/comments',
#     'statuses_url': 'https://api.github.com/repos/vader26/save-nature/statuses/c76f087674016cff35afaa5376d2f3e5cff9b62c',
#     'head': {'label': 'vader26:dependabot/npm_and_yarn/websocket-extensions-0.1.4',
#      'ref': 'dependabot/npm_and_yarn/websocket-extensions-0.1.4',
#      'sha': 'c76f087674016cff35afaa5376d2f3e5cff9b62c',
#      'user': {'login': 'vader26',
#       'id': 32021661,
#       'node_id': 'MDQ6VXNlcjMyMDIxNjYx',
#       'avatar_url': 'https://avatars2.githubusercontent.com/u/32021661?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/vader26',
#       'html_url': 'https://github.com/vader26',
#       'followers_url': 'https://api.github.com/users/vader26/followers',
#       'following_url': 'https://api.github.com/users/vader26/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/vader26/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/vader26/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/vader26/subscriptions',
#       'organizations_url': 'https://api.github.com/users/vader26/orgs',
#       'repos_url': 'https://api.github.com/users/vader26/repos',
#       'events_url': 'https://api.github.com/users/vader26/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/vader26/received_events',
#       'type': 'User',
#       'site_admin': False},
#      'repo': {'id': 272711428,
#       'node_id': 'MDEwOlJlcG9zaXRvcnkyNzI3MTE0Mjg=',
#       'name': 'save-nature',
#       'full_name': 'vader26/save-nature',
#       'private': False,
#       'owner': {'login': 'vader26',
#        'id': 32021661,
#        'node_id': 'MDQ6VXNlcjMyMDIxNjYx',
#        'avatar_url': 'https://avatars2.githubusercontent.com/u/32021661?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/vader26',
#        'html_url': 'https://github.com/vader26',
#        'followers_url': 'https://api.github.com/users/vader26/followers',
#        'following_url': 'https://api.github.com/users/vader26/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/vader26/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/vader26/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/vader26/subscriptions',
#        'organizations_url': 'https://api.github.com/users/vader26/orgs',
#        'repos_url': 'https://api.github.com/users/vader26/repos',
#        'events_url': 'https://api.github.com/users/vader26/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/vader26/received_events',
#        'type': 'User',
#        'site_admin': False},
#       'html_url': 'https://github.com/vader26/save-nature',
#       'description': None,
#       'fork': False,
#       'url': 'https://api.github.com/repos/vader26/save-nature',
#       'forks_url': 'https://api.github.com/repos/vader26/save-nature/forks',
#       'keys_url': 'https://api.github.com/repos/vader26/save-nature/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/vader26/save-nature/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/vader26/save-nature/teams',
#       'hooks_url': 'https://api.github.com/repos/vader26/save-nature/hooks',
#       'issue_events_url': 'https://api.github.com/repos/vader26/save-nature/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/vader26/save-nature/events',
#       'assignees_url': 'https://api.github.com/repos/vader26/save-nature/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/vader26/save-nature/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/vader26/save-nature/tags',
#       'blobs_url': 'https://api.github.com/repos/vader26/save-nature/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/vader26/save-nature/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/vader26/save-nature/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/vader26/save-nature/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/vader26/save-nature/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/vader26/save-nature/languages',
#       'stargazers_url': 'https://api.github.com/repos/vader26/save-nature/stargazers',
#       'contributors_url': 'https://api.github.com/repos/vader26/save-nature/contributors',
#       'subscribers_url': 'https://api.github.com/repos/vader26/save-nature/subscribers',
#       'subscription_url': 'https://api.github.com/repos/vader26/save-nature/subscription',
#       'commits_url': 'https://api.github.com/repos/vader26/save-nature/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/vader26/save-nature/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/vader26/save-nature/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/vader26/save-nature/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/vader26/save-nature/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/vader26/save-nature/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/vader26/save-nature/merges',
#       'archive_url': 'https://api.github.com/repos/vader26/save-nature/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/vader26/save-nature/downloads',
#       'issues_url': 'https://api.github.com/repos/vader26/save-nature/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/vader26/save-nature/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/vader26/save-nature/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/vader26/save-nature/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/vader26/save-nature/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/vader26/save-nature/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/vader26/save-nature/deployments',
#       'created_at': '2020-06-16T13:11:02Z',
#       'updated_at': '2020-06-16T13:11:38Z',
#       'pushed_at': '2020-06-16T13:12:38Z',
#       'git_url': 'git://github.com/vader26/save-nature.git',
#       'ssh_url': 'git@github.com:vader26/save-nature.git',
#       'clone_url': 'https://github.com/vader26/save-nature.git',
#       'svn_url': 'https://github.com/vader26/save-nature',
#       'homepage': None,
#       'size': 0,
#       'stargazers_count': 0,
#       'watchers_count': 0,
#       'language': 'Vue',
#       'has_issues': True,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': True,
#       'has_pages': False,
#       'forks_count': 0,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 1,
#       'license': None,
#       'forks': 0,
#       'open_issues': 1,
#       'watchers': 0,
#       'default_branch': 'master'}},
#     'base': {'label': 'vader26:master',
#      'ref': 'master',
#      'sha': '23411ac21aaadf0b4c1e7e16a906fdf685d18e64',
#      'user': {'login': 'vader26',
#       'id': 32021661,
#       'node_id': 'MDQ6VXNlcjMyMDIxNjYx',
#       'avatar_url': 'https://avatars2.githubusercontent.com/u/32021661?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/vader26',
#       'html_url': 'https://github.com/vader26',
#       'followers_url': 'https://api.github.com/users/vader26/followers',
#       'following_url': 'https://api.github.com/users/vader26/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/vader26/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/vader26/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/vader26/subscriptions',
#       'organizations_url': 'https://api.github.com/users/vader26/orgs',
#       'repos_url': 'https://api.github.com/users/vader26/repos',
#       'events_url': 'https://api.github.com/users/vader26/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/vader26/received_events',
#       'type': 'User',
#       'site_admin': False},
#      'repo': {'id': 272711428,
#       'node_id': 'MDEwOlJlcG9zaXRvcnkyNzI3MTE0Mjg=',
#       'name': 'save-nature',
#       'full_name': 'vader26/save-nature',
#       'private': False,
#       'owner': {'login': 'vader26',
#        'id': 32021661,
#        'node_id': 'MDQ6VXNlcjMyMDIxNjYx',
#        'avatar_url': 'https://avatars2.githubusercontent.com/u/32021661?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/vader26',
#        'html_url': 'https://github.com/vader26',
#        'followers_url': 'https://api.github.com/users/vader26/followers',
#        'following_url': 'https://api.github.com/users/vader26/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/vader26/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/vader26/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/vader26/subscriptions',
#        'organizations_url': 'https://api.github.com/users/vader26/orgs',
#        'repos_url': 'https://api.github.com/users/vader26/repos',
#        'events_url': 'https://api.github.com/users/vader26/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/vader26/received_events',
#        'type': 'User',
#        'site_admin': False},
#       'html_url': 'https://github.com/vader26/save-nature',
#       'description': None,
#       'fork': False,
#       'url': 'https://api.github.com/repos/vader26/save-nature',
#       'forks_url': 'https://api.github.com/repos/vader26/save-nature/forks',
#       'keys_url': 'https://api.github.com/repos/vader26/save-nature/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/vader26/save-nature/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/vader26/save-nature/teams',
#       'hooks_url': 'https://api.github.com/repos/vader26/save-nature/hooks',
#       'issue_events_url': 'https://api.github.com/repos/vader26/save-nature/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/vader26/save-nature/events',
#       'assignees_url': 'https://api.github.com/repos/vader26/save-nature/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/vader26/save-nature/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/vader26/save-nature/tags',
#       'blobs_url': 'https://api.github.com/repos/vader26/save-nature/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/vader26/save-nature/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/vader26/save-nature/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/vader26/save-nature/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/vader26/save-nature/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/vader26/save-nature/languages',
#       'stargazers_url': 'https://api.github.com/repos/vader26/save-nature/stargazers',
#       'contributors_url': 'https://api.github.com/repos/vader26/save-nature/contributors',
#       'subscribers_url': 'https://api.github.com/repos/vader26/save-nature/subscribers',
#       'subscription_url': 'https://api.github.com/repos/vader26/save-nature/subscription',
#       'commits_url': 'https://api.github.com/repos/vader26/save-nature/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/vader26/save-nature/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/vader26/save-nature/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/vader26/save-nature/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/vader26/save-nature/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/vader26/save-nature/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/vader26/save-nature/merges',
#       'archive_url': 'https://api.github.com/repos/vader26/save-nature/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/vader26/save-nature/downloads',
#       'issues_url': 'https://api.github.com/repos/vader26/save-nature/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/vader26/save-nature/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/vader26/save-nature/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/vader26/save-nature/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/vader26/save-nature/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/vader26/save-nature/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/vader26/save-nature/deployments',
#       'created_at': '2020-06-16T13:11:02Z',
#       'updated_at': '2020-06-16T13:11:38Z',
#       'pushed_at': '2020-06-16T13:12:38Z',
#       'git_url': 'git://github.com/vader26/save-nature.git',
#       'ssh_url': 'git@github.com:vader26/save-nature.git',
#       'clone_url': 'https://github.com/vader26/save-nature.git',
#       'svn_url': 'https://github.com/vader26/save-nature',
#       'homepage': None,
#       'size': 0,
#       'stargazers_count': 0,
#       'watchers_count': 0,
#       'language': 'Vue',
#       'has_issues': True,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': True,
#       'has_pages': False,
#       'forks_count': 0,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 1,
#       'license': None,
#       'forks': 0,
#       'open_issues': 1,
#       'watchers': 0,
#       'default_branch': 'master'}},
#     '_links': {'self': {'href': 'https://api.github.com/repos/vader26/save-nature/pulls/1'},
#      'html': {'href': 'https://github.com/vader26/save-nature/pull/1'},
#      'issue': {'href': 'https://api.github.com/repos/vader26/save-nature/issues/1'},
#      'comments': {'href': 'https://api.github.com/repos/vader26/save-nature/issues/1/comments'},
#      'review_comments': {'href': 'https://api.github.com/repos/vader26/save-nature/pulls/1/comments'},
#      'review_comment': {'href': 'https://api.github.com/repos/vader26/save-nature/pulls/comments{/number}'},
#      'commits': {'href': 'https://api.github.com/repos/vader26/save-nature/pulls/1/commits'},
#      'statuses': {'href': 'https://api.github.com/repos/vader26/save-nature/statuses/c76f087674016cff35afaa5376d2f3e5cff9b62c'}},
#     'author_association': 'NONE',
#     'active_lock_reason': None,
#     'merged': False,
#     'mergeable': None,
#     'rebaseable': None,
#     'mergeable_state': 'unknown',
#     'merged_by': None,
#     'comments': 0,
#     'review_comments': 0,
#     'maintainer_can_modify': False,
#     'commits': 1,
#     'additions': 3,
#     'deletions': 3,
#     'changed_files': 1}},
#   'public': True,
#   'created_at': '2020-06-16T13:12:39Z'},
#  {'id': '12645382319',
#   'type': 'PullRequestEvent',
#   'actor': {'id': 53178108,
#    'login': 'SanjayMindinventory',
#    'display_login': 'SanjayMindinventory',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/SanjayMindinventory',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/53178108?'},
#   'repo': {'id': 263032972,
#    'name': 'changeup-io/change-up',
#    'url': 'https://api.github.com/repos/changeup-io/change-up'},
#   'payload': {'action': 'closed',
#    'number': 4,
#    'pull_request': {'url': 'https://api.github.com/repos/changeup-io/change-up/pulls/4',
#     'id': 435202237,
#     'node_id': 'MDExOlB1bGxSZXF1ZXN0NDM1MjAyMjM3',
#     'html_url': 'https://github.com/changeup-io/change-up/pull/4',
#     'diff_url': 'https://github.com/changeup-io/change-up/pull/4.diff',
#     'patch_url': 'https://github.com/changeup-io/change-up/pull/4.patch',
#     'issue_url': 'https://api.github.com/repos/changeup-io/change-up/issues/4',
#     'number': 4,
#     'state': 'closed',
#     'locked': False,
#     'title': 'Development',
#     'user': {'login': 'SanjayMindinventory',
#      'id': 53178108,
#      'node_id': 'MDQ6VXNlcjUzMTc4MTA4',
#      'avatar_url': 'https://avatars2.githubusercontent.com/u/53178108?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/SanjayMindinventory',
#      'html_url': 'https://github.com/SanjayMindinventory',
#      'followers_url': 'https://api.github.com/users/SanjayMindinventory/followers',
#      'following_url': 'https://api.github.com/users/SanjayMindinventory/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/SanjayMindinventory/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/SanjayMindinventory/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/SanjayMindinventory/subscriptions',
#      'organizations_url': 'https://api.github.com/users/SanjayMindinventory/orgs',
#      'repos_url': 'https://api.github.com/users/SanjayMindinventory/repos',
#      'events_url': 'https://api.github.com/users/SanjayMindinventory/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/SanjayMindinventory/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'body': '',
#     'created_at': '2020-06-16T13:08:23Z',
#     'updated_at': '2020-06-16T13:12:39Z',
#     'closed_at': '2020-06-16T13:12:39Z',
#     'merged_at': None,
#     'merge_commit_sha': '9d58581a4bc10d41773ef010624082a3f7bc2023',
#     'assignee': None,
#     'assignees': [],
#     'requested_reviewers': [],
#     'requested_teams': [],
#     'labels': [],
#     'milestone': None,
#     'draft': False,
#     'commits_url': 'https://api.github.com/repos/changeup-io/change-up/pulls/4/commits',
#     'review_comments_url': 'https://api.github.com/repos/changeup-io/change-up/pulls/4/comments',
#     'review_comment_url': 'https://api.github.com/repos/changeup-io/change-up/pulls/comments{/number}',
#     'comments_url': 'https://api.github.com/repos/changeup-io/change-up/issues/4/comments',
#     'statuses_url': 'https://api.github.com/repos/changeup-io/change-up/statuses/4ad8b372ae0a3668a4918d0e4a3656936fb15f46',
#     'head': {'label': 'changeup-io:development',
#      'ref': 'development',
#      'sha': '4ad8b372ae0a3668a4918d0e4a3656936fb15f46',
#      'user': {'login': 'changeup-io',
#       'id': 64266286,
#       'node_id': 'MDEyOk9yZ2FuaXphdGlvbjY0MjY2Mjg2',
#       'avatar_url': 'https://avatars2.githubusercontent.com/u/64266286?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/changeup-io',
#       'html_url': 'https://github.com/changeup-io',
#       'followers_url': 'https://api.github.com/users/changeup-io/followers',
#       'following_url': 'https://api.github.com/users/changeup-io/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/changeup-io/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/changeup-io/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/changeup-io/subscriptions',
#       'organizations_url': 'https://api.github.com/users/changeup-io/orgs',
#       'repos_url': 'https://api.github.com/users/changeup-io/repos',
#       'events_url': 'https://api.github.com/users/changeup-io/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/changeup-io/received_events',
#       'type': 'Organization',
#       'site_admin': False},
#      'repo': {'id': 263032972,
#       'node_id': 'MDEwOlJlcG9zaXRvcnkyNjMwMzI5NzI=',
#       'name': 'change-up',
#       'full_name': 'changeup-io/change-up',
#       'private': False,
#       'owner': {'login': 'changeup-io',
#        'id': 64266286,
#        'node_id': 'MDEyOk9yZ2FuaXphdGlvbjY0MjY2Mjg2',
#        'avatar_url': 'https://avatars2.githubusercontent.com/u/64266286?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/changeup-io',
#        'html_url': 'https://github.com/changeup-io',
#        'followers_url': 'https://api.github.com/users/changeup-io/followers',
#        'following_url': 'https://api.github.com/users/changeup-io/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/changeup-io/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/changeup-io/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/changeup-io/subscriptions',
#        'organizations_url': 'https://api.github.com/users/changeup-io/orgs',
#        'repos_url': 'https://api.github.com/users/changeup-io/repos',
#        'events_url': 'https://api.github.com/users/changeup-io/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/changeup-io/received_events',
#        'type': 'Organization',
#        'site_admin': False},
#       'html_url': 'https://github.com/changeup-io/change-up',
#       'description': None,
#       'fork': True,
#       'url': 'https://api.github.com/repos/changeup-io/change-up',
#       'forks_url': 'https://api.github.com/repos/changeup-io/change-up/forks',
#       'keys_url': 'https://api.github.com/repos/changeup-io/change-up/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/changeup-io/change-up/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/changeup-io/change-up/teams',
#       'hooks_url': 'https://api.github.com/repos/changeup-io/change-up/hooks',
#       'issue_events_url': 'https://api.github.com/repos/changeup-io/change-up/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/changeup-io/change-up/events',
#       'assignees_url': 'https://api.github.com/repos/changeup-io/change-up/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/changeup-io/change-up/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/changeup-io/change-up/tags',
#       'blobs_url': 'https://api.github.com/repos/changeup-io/change-up/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/changeup-io/change-up/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/changeup-io/change-up/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/changeup-io/change-up/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/changeup-io/change-up/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/changeup-io/change-up/languages',
#       'stargazers_url': 'https://api.github.com/repos/changeup-io/change-up/stargazers',
#       'contributors_url': 'https://api.github.com/repos/changeup-io/change-up/contributors',
#       'subscribers_url': 'https://api.github.com/repos/changeup-io/change-up/subscribers',
#       'subscription_url': 'https://api.github.com/repos/changeup-io/change-up/subscription',
#       'commits_url': 'https://api.github.com/repos/changeup-io/change-up/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/changeup-io/change-up/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/changeup-io/change-up/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/changeup-io/change-up/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/changeup-io/change-up/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/changeup-io/change-up/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/changeup-io/change-up/merges',
#       'archive_url': 'https://api.github.com/repos/changeup-io/change-up/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/changeup-io/change-up/downloads',
#       'issues_url': 'https://api.github.com/repos/changeup-io/change-up/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/changeup-io/change-up/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/changeup-io/change-up/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/changeup-io/change-up/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/changeup-io/change-up/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/changeup-io/change-up/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/changeup-io/change-up/deployments',
#       'created_at': '2020-05-11T12:15:23Z',
#       'updated_at': '2020-06-04T13:20:17Z',
#       'pushed_at': '2020-06-16T13:08:24Z',
#       'git_url': 'git://github.com/changeup-io/change-up.git',
#       'ssh_url': 'git@github.com:changeup-io/change-up.git',
#       'clone_url': 'https://github.com/changeup-io/change-up.git',
#       'svn_url': 'https://github.com/changeup-io/change-up',
#       'homepage': None,
#       'size': 1585,
#       'stargazers_count': 0,
#       'watchers_count': 0,
#       'language': 'JavaScript',
#       'has_issues': False,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': True,
#       'has_pages': False,
#       'forks_count': 0,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 1,
#       'license': None,
#       'forks': 0,
#       'open_issues': 1,
#       'watchers': 0,
#       'default_branch': 'master'}},
#     'base': {'label': 'changeup-io:master',
#      'ref': 'master',
#      'sha': 'cf5f4499ad97b2b84382b964b2759aea5df5e16f',
#      'user': {'login': 'changeup-io',
#       'id': 64266286,
#       'node_id': 'MDEyOk9yZ2FuaXphdGlvbjY0MjY2Mjg2',
#       'avatar_url': 'https://avatars2.githubusercontent.com/u/64266286?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/changeup-io',
#       'html_url': 'https://github.com/changeup-io',
#       'followers_url': 'https://api.github.com/users/changeup-io/followers',
#       'following_url': 'https://api.github.com/users/changeup-io/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/changeup-io/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/changeup-io/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/changeup-io/subscriptions',
#       'organizations_url': 'https://api.github.com/users/changeup-io/orgs',
#       'repos_url': 'https://api.github.com/users/changeup-io/repos',
#       'events_url': 'https://api.github.com/users/changeup-io/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/changeup-io/received_events',
#       'type': 'Organization',
#       'site_admin': False},
#      'repo': {'id': 263032972,
#       'node_id': 'MDEwOlJlcG9zaXRvcnkyNjMwMzI5NzI=',
#       'name': 'change-up',
#       'full_name': 'changeup-io/change-up',
#       'private': False,
#       'owner': {'login': 'changeup-io',
#        'id': 64266286,
#        'node_id': 'MDEyOk9yZ2FuaXphdGlvbjY0MjY2Mjg2',
#        'avatar_url': 'https://avatars2.githubusercontent.com/u/64266286?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/changeup-io',
#        'html_url': 'https://github.com/changeup-io',
#        'followers_url': 'https://api.github.com/users/changeup-io/followers',
#        'following_url': 'https://api.github.com/users/changeup-io/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/changeup-io/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/changeup-io/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/changeup-io/subscriptions',
#        'organizations_url': 'https://api.github.com/users/changeup-io/orgs',
#        'repos_url': 'https://api.github.com/users/changeup-io/repos',
#        'events_url': 'https://api.github.com/users/changeup-io/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/changeup-io/received_events',
#        'type': 'Organization',
#        'site_admin': False},
#       'html_url': 'https://github.com/changeup-io/change-up',
#       'description': None,
#       'fork': True,
#       'url': 'https://api.github.com/repos/changeup-io/change-up',
#       'forks_url': 'https://api.github.com/repos/changeup-io/change-up/forks',
#       'keys_url': 'https://api.github.com/repos/changeup-io/change-up/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/changeup-io/change-up/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/changeup-io/change-up/teams',
#       'hooks_url': 'https://api.github.com/repos/changeup-io/change-up/hooks',
#       'issue_events_url': 'https://api.github.com/repos/changeup-io/change-up/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/changeup-io/change-up/events',
#       'assignees_url': 'https://api.github.com/repos/changeup-io/change-up/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/changeup-io/change-up/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/changeup-io/change-up/tags',
#       'blobs_url': 'https://api.github.com/repos/changeup-io/change-up/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/changeup-io/change-up/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/changeup-io/change-up/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/changeup-io/change-up/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/changeup-io/change-up/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/changeup-io/change-up/languages',
#       'stargazers_url': 'https://api.github.com/repos/changeup-io/change-up/stargazers',
#       'contributors_url': 'https://api.github.com/repos/changeup-io/change-up/contributors',
#       'subscribers_url': 'https://api.github.com/repos/changeup-io/change-up/subscribers',
#       'subscription_url': 'https://api.github.com/repos/changeup-io/change-up/subscription',
#       'commits_url': 'https://api.github.com/repos/changeup-io/change-up/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/changeup-io/change-up/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/changeup-io/change-up/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/changeup-io/change-up/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/changeup-io/change-up/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/changeup-io/change-up/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/changeup-io/change-up/merges',
#       'archive_url': 'https://api.github.com/repos/changeup-io/change-up/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/changeup-io/change-up/downloads',
#       'issues_url': 'https://api.github.com/repos/changeup-io/change-up/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/changeup-io/change-up/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/changeup-io/change-up/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/changeup-io/change-up/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/changeup-io/change-up/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/changeup-io/change-up/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/changeup-io/change-up/deployments',
#       'created_at': '2020-05-11T12:15:23Z',
#       'updated_at': '2020-06-04T13:20:17Z',
#       'pushed_at': '2020-06-16T13:08:24Z',
#       'git_url': 'git://github.com/changeup-io/change-up.git',
#       'ssh_url': 'git@github.com:changeup-io/change-up.git',
#       'clone_url': 'https://github.com/changeup-io/change-up.git',
#       'svn_url': 'https://github.com/changeup-io/change-up',
#       'homepage': None,
#       'size': 1585,
#       'stargazers_count': 0,
#       'watchers_count': 0,
#       'language': 'JavaScript',
#       'has_issues': False,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': True,
#       'has_pages': False,
#       'forks_count': 0,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 1,
#       'license': None,
#       'forks': 0,
#       'open_issues': 1,
#       'watchers': 0,
#       'default_branch': 'master'}},
#     '_links': {'self': {'href': 'https://api.github.com/repos/changeup-io/change-up/pulls/4'},
#      'html': {'href': 'https://github.com/changeup-io/change-up/pull/4'},
#      'issue': {'href': 'https://api.github.com/repos/changeup-io/change-up/issues/4'},
#      'comments': {'href': 'https://api.github.com/repos/changeup-io/change-up/issues/4/comments'},
#      'review_comments': {'href': 'https://api.github.com/repos/changeup-io/change-up/pulls/4/comments'},
#      'review_comment': {'href': 'https://api.github.com/repos/changeup-io/change-up/pulls/comments{/number}'},
#      'commits': {'href': 'https://api.github.com/repos/changeup-io/change-up/pulls/4/commits'},
#      'statuses': {'href': 'https://api.github.com/repos/changeup-io/change-up/statuses/4ad8b372ae0a3668a4918d0e4a3656936fb15f46'}},
#     'author_association': 'COLLABORATOR',
#     'active_lock_reason': None,
#     'merged': False,
#     'mergeable': True,
#     'rebaseable': True,
#     'mergeable_state': 'unstable',
#     'merged_by': None,
#     'comments': 0,
#     'review_comments': 0,
#     'maintainer_can_modify': False,
#     'commits': 5,
#     'additions': 255,
#     'deletions': 283,
#     'changed_files': 10}},
#   'public': True,
#   'created_at': '2020-06-16T13:12:39Z',
#   'org': {'id': 64266286,
#    'login': 'changeup-io',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/changeup-io',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/64266286?'}},
#  {'id': '12645382307',
#   'type': 'PushEvent',
#   'actor': {'id': 10113203,
#    'login': 'MAbhu',
#    'display_login': 'MAbhu',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/MAbhu',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/10113203?'},
#   'repo': {'id': 271996766,
#    'name': 'MAbhu/Dragon-Fly',
#    'url': 'https://api.github.com/repos/MAbhu/Dragon-Fly'},
#   'payload': {'push_id': 5237139624,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '366a73a3b15facf939a4fed415a8e50fab18c473',
#    'before': '1410e8e376b7653a0d4c173bd0b3fcd885a81f30',
#    'commits': [{'sha': '366a73a3b15facf939a4fed415a8e50fab18c473',
#      'author': {'email': 'ad_abhu@hotmail.com', 'name': 'Abhishek'},
#      'message': 'Implemeted the dragon movement',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/MAbhu/Dragon-Fly/commits/366a73a3b15facf939a4fed415a8e50fab18c473'}]},
#   'public': True,
#   'created_at': '2020-06-16T13:12:39Z'},
#  {'id': '12645382309',
#   'type': 'PushEvent',
#   'actor': {'id': 66999345,
#    'login': 'dredowan',
#    'display_login': 'dredowan',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/dredowan',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/66999345?'},
#   'repo': {'id': 272695800,
#    'name': 'dredowan/dredowan.github.io',
#    'url': 'https://api.github.com/repos/dredowan/dredowan.github.io'},
#   'payload': {'push_id': 5237139625,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '0a7047a7047b64e52317d436edfa79819b4dbb9c',
#    'before': '8df8b92d42d7f59fb165a8814cf9ccdffeae9c56',
#    'commits': [{'sha': '0a7047a7047b64e52317d436edfa79819b4dbb9c',
#      'author': {'email': '66999345+dredowan@users.noreply.github.com',
# ...
#        'received_events_url': 'https://api.github.com/users/Sakarisson/received_events',
#        'type': 'User',
#        'site_admin': False},
#       'html_url': 'https://github.com/Sakarisson/react-native-modal',
#       'description': 'An enhanced, animated and customizable react-native modal',
#       'fork': True,
#       'url': 'https://api.github.com/repos/Sakarisson/react-native-modal',
#       'forks_url': 'https://api.github.com/repos/Sakarisson/react-native-modal/forks',
#       'keys_url': 'https://api.github.com/repos/Sakarisson/react-native-modal/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/Sakarisson/react-native-modal/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/Sakarisson/react-native-modal/teams',
#       'hooks_url': 'https://api.github.com/repos/Sakarisson/react-native-modal/hooks',
#       'issue_events_url': 'https://api.github.com/repos/Sakarisson/react-native-modal/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/Sakarisson/react-native-modal/events',
#       'assignees_url': 'https://api.github.com/repos/Sakarisson/react-native-modal/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/Sakarisson/react-native-modal/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/Sakarisson/react-native-modal/tags',
#       'blobs_url': 'https://api.github.com/repos/Sakarisson/react-native-modal/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/Sakarisson/react-native-modal/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/Sakarisson/react-native-modal/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/Sakarisson/react-native-modal/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/Sakarisson/react-native-modal/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/Sakarisson/react-native-modal/languages',
#       'stargazers_url': 'https://api.github.com/repos/Sakarisson/react-native-modal/stargazers',
#       'contributors_url': 'https://api.github.com/repos/Sakarisson/react-native-modal/contributors',
#       'subscribers_url': 'https://api.github.com/repos/Sakarisson/react-native-modal/subscribers',
#       'subscription_url': 'https://api.github.com/repos/Sakarisson/react-native-modal/subscription',
#       'commits_url': 'https://api.github.com/repos/Sakarisson/react-native-modal/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/Sakarisson/react-native-modal/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/Sakarisson/react-native-modal/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/Sakarisson/react-native-modal/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/Sakarisson/react-native-modal/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/Sakarisson/react-native-modal/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/Sakarisson/react-native-modal/merges',
#       'archive_url': 'https://api.github.com/repos/Sakarisson/react-native-modal/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/Sakarisson/react-native-modal/downloads',
#       'issues_url': 'https://api.github.com/repos/Sakarisson/react-native-modal/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/Sakarisson/react-native-modal/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/Sakarisson/react-native-modal/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/Sakarisson/react-native-modal/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/Sakarisson/react-native-modal/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/Sakarisson/react-native-modal/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/Sakarisson/react-native-modal/deployments',
#       'created_at': '2020-06-16T13:08:07Z',
#       'updated_at': '2020-06-16T13:09:57Z',
#       'pushed_at': '2020-06-16T13:09:54Z',
#       'git_url': 'git://github.com/Sakarisson/react-native-modal.git',
#       'ssh_url': 'git@github.com:Sakarisson/react-native-modal.git',
#       'clone_url': 'https://github.com/Sakarisson/react-native-modal.git',
#       'svn_url': 'https://github.com/Sakarisson/react-native-modal',
#       'homepage': '',
#       'size': 8520,
#       'stargazers_count': 0,
#       'watchers_count': 0,
#       'language': 'TypeScript',
#       'has_issues': False,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': True,
#       'has_pages': False,
#       'forks_count': 0,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 0,
#       'license': {'key': 'mit',
#        'name': 'MIT License',
#        'spdx_id': 'MIT',
#        'url': 'https://api.github.com/licenses/mit',
#        'node_id': 'MDc6TGljZW5zZTEz'},
#       'forks': 0,
#       'open_issues': 0,
#       'watchers': 0,
#       'default_branch': 'master'}},
#     'base': {'label': 'react-native-community:master',
#      'ref': 'master',
#      'sha': 'b346e1e17d2179a4f199dee82ffd12628bb731eb',
#      'user': {'login': 'react-native-community',
#       'id': 20269980,
#       'node_id': 'MDEyOk9yZ2FuaXphdGlvbjIwMjY5OTgw',
#       'avatar_url': 'https://avatars1.githubusercontent.com/u/20269980?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/react-native-community',
#       'html_url': 'https://github.com/react-native-community',
#       'followers_url': 'https://api.github.com/users/react-native-community/followers',
#       'following_url': 'https://api.github.com/users/react-native-community/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/react-native-community/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/react-native-community/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/react-native-community/subscriptions',
#       'organizations_url': 'https://api.github.com/users/react-native-community/orgs',
#       'repos_url': 'https://api.github.com/users/react-native-community/repos',
#       'events_url': 'https://api.github.com/users/react-native-community/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/react-native-community/received_events',
#       'type': 'Organization',
#       'site_admin': False},
#      'repo': {'id': 69043435,
#       'node_id': 'MDEwOlJlcG9zaXRvcnk2OTA0MzQzNQ==',
#       'name': 'react-native-modal',
#       'full_name': 'react-native-community/react-native-modal',
#       'private': False,
#       'owner': {'login': 'react-native-community',
#        'id': 20269980,
#        'node_id': 'MDEyOk9yZ2FuaXphdGlvbjIwMjY5OTgw',
#        'avatar_url': 'https://avatars1.githubusercontent.com/u/20269980?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/react-native-community',
#        'html_url': 'https://github.com/react-native-community',
#        'followers_url': 'https://api.github.com/users/react-native-community/followers',
#        'following_url': 'https://api.github.com/users/react-native-community/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/react-native-community/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/react-native-community/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/react-native-community/subscriptions',
#        'organizations_url': 'https://api.github.com/users/react-native-community/orgs',
#        'repos_url': 'https://api.github.com/users/react-native-community/repos',
#        'events_url': 'https://api.github.com/users/react-native-community/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/react-native-community/received_events',
#        'type': 'Organization',
#        'site_admin': False},
#       'html_url': 'https://github.com/react-native-community/react-native-modal',
#       'description': 'An enhanced, animated and customizable react-native modal',
#       'fork': False,
#       'url': 'https://api.github.com/repos/react-native-community/react-native-modal',
#       'forks_url': 'https://api.github.com/repos/react-native-community/react-native-modal/forks',
#       'keys_url': 'https://api.github.com/repos/react-native-community/react-native-modal/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/react-native-community/react-native-modal/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/react-native-community/react-native-modal/teams',
#       'hooks_url': 'https://api.github.com/repos/react-native-community/react-native-modal/hooks',
#       'issue_events_url': 'https://api.github.com/repos/react-native-community/react-native-modal/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/react-native-community/react-native-modal/events',
#       'assignees_url': 'https://api.github.com/repos/react-native-community/react-native-modal/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/react-native-community/react-native-modal/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/react-native-community/react-native-modal/tags',
#       'blobs_url': 'https://api.github.com/repos/react-native-community/react-native-modal/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/react-native-community/react-native-modal/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/react-native-community/react-native-modal/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/react-native-community/react-native-modal/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/react-native-community/react-native-modal/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/react-native-community/react-native-modal/languages',
#       'stargazers_url': 'https://api.github.com/repos/react-native-community/react-native-modal/stargazers',
#       'contributors_url': 'https://api.github.com/repos/react-native-community/react-native-modal/contributors',
#       'subscribers_url': 'https://api.github.com/repos/react-native-community/react-native-modal/subscribers',
#       'subscription_url': 'https://api.github.com/repos/react-native-community/react-native-modal/subscription',
#       'commits_url': 'https://api.github.com/repos/react-native-community/react-native-modal/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/react-native-community/react-native-modal/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/react-native-community/react-native-modal/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/react-native-community/react-native-modal/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/react-native-community/react-native-modal/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/react-native-community/react-native-modal/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/react-native-community/react-native-modal/merges',
#       'archive_url': 'https://api.github.com/repos/react-native-community/react-native-modal/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/react-native-community/react-native-modal/downloads',
#       'issues_url': 'https://api.github.com/repos/react-native-community/react-native-modal/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/react-native-community/react-native-modal/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/react-native-community/react-native-modal/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/react-native-community/react-native-modal/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/react-native-community/react-native-modal/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/react-native-community/react-native-modal/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/react-native-community/react-native-modal/deployments',
#       'created_at': '2016-09-23T16:45:46Z',
#       'updated_at': '2020-06-15T03:07:25Z',
#       'pushed_at': '2020-05-28T14:31:06Z',
#       'git_url': 'git://github.com/react-native-community/react-native-modal.git',
#       'ssh_url': 'git@github.com:react-native-community/react-native-modal.git',
#       'clone_url': 'https://github.com/react-native-community/react-native-modal.git',
#       'svn_url': 'https://github.com/react-native-community/react-native-modal',
#       'homepage': '',
#       'size': 8520,
#       'stargazers_count': 3588,
#       'watchers_count': 3588,
#       'language': 'TypeScript',
#       'has_issues': True,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': True,
#       'has_pages': False,
#       'forks_count': 452,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 41,
#       'license': {'key': 'mit',
#        'name': 'MIT License',
#        'spdx_id': 'MIT',
#        'url': 'https://api.github.com/licenses/mit',
#        'node_id': 'MDc6TGljZW5zZTEz'},
#       'forks': 452,
#       'open_issues': 41,
#       'watchers': 3588,
#       'default_branch': 'master'}},
#     '_links': {'self': {'href': 'https://api.github.com/repos/react-native-community/react-native-modal/pulls/450'},
#      'html': {'href': 'https://github.com/react-native-community/react-native-modal/pull/450'},
#      'issue': {'href': 'https://api.github.com/repos/react-native-community/react-native-modal/issues/450'},
#      'comments': {'href': 'https://api.github.com/repos/react-native-community/react-native-modal/issues/450/comments'},
#      'review_comments': {'href': 'https://api.github.com/repos/react-native-community/react-native-modal/pulls/450/comments'},
#      'review_comment': {'href': 'https://api.github.com/repos/react-native-community/react-native-modal/pulls/comments{/number}'},
#      'commits': {'href': 'https://api.github.com/repos/react-native-community/react-native-modal/pulls/450/commits'},
#      'statuses': {'href': 'https://api.github.com/repos/react-native-community/react-native-modal/statuses/ca6fd12daeffdd20da79949669fe1a0779d0c89d'}},
#     'author_association': 'NONE',
#     'active_lock_reason': None,
#     'merged': False,
#     'mergeable': None,
#     'rebaseable': None,
#     'mergeable_state': 'unknown',
#     'merged_by': None,
#     'comments': 0,
#     'review_comments': 0,
#     'maintainer_can_modify': True,
#     'commits': 1,
#     'additions': 85,
#     'deletions': 78,
#     'changed_files': 1}},
#   'public': True,
#   'created_at': '2020-06-16T13:12:39Z',
#   'org': {'id': 20269980,
#    'login': 'react-native-community',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/react-native-community',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/20269980?'}},
#  {'id': '12645382208',
#   'type': 'PushEvent',
#   'actor': {'id': 15207117,
#    'login': 'geravolobuev',
#    'display_login': 'geravolobuev',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/geravolobuev',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/15207117?'},
#   'repo': {'id': 223934088,
#    'name': 'geravolobuev/YATMA',
#    'url': 'https://api.github.com/repos/geravolobuev/YATMA'},
#   'payload': {'push_id': 5237139574,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': 'd37a26b4224e01af1f25d59b352ce286c2eebd9d',
#    'before': '13f067217f4514e79f461d00df7ee9ac7594dd1c',
#    'commits': [{'sha': 'd37a26b4224e01af1f25d59b352ce286c2eebd9d',
#      'author': {'email': 'fromgayva@gmail.com', 'name': 'Gio'},
#      'message': 'Update README.md',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/geravolobuev/YATMA/commits/d37a26b4224e01af1f25d59b352ce286c2eebd9d'}]},
#   'public': True,
#   'created_at': '2020-06-16T13:12:39Z'}]

# %% [markdown]
# ## 其它用法
# 參閱：https://blog.gtwang.org/programming/python-requests-module-tutorial/

# %%
payload = {'key1': 'value1', 'key2': 'value2'}
r = requests.get("http://httpbin.org/get", params=payload)
json.loads(r.text)
# Out:
# {'args': {'key1': 'value1', 'key2': 'value2'},
#  'headers': {'Accept': '*/*',
#   'Accept-Encoding': 'gzip, deflate',
#   'Host': 'httpbin.org',
#   'User-Agent': 'python-requests/2.23.0',
#   'X-Amzn-Trace-Id': 'Root=1-5ee8c674-6286fba835c7274be97772ac'},
#  'origin': '1.162.97.8',
#  'url': 'http://httpbin.org/get?key1=value1&key2=value2'}

# %%
r = requests.post('http://httpbin.org/post', data = {'key':'value'})
json.loads(r.text)
# Out:
# {'args': {},
#  'data': '',
#  'files': {},
#  'form': {'key': 'value'},
#  'headers': {'Accept': '*/*',
#   'Accept-Encoding': 'gzip, deflate',
#   'Content-Length': '9',
#   'Content-Type': 'application/x-www-form-urlencoded',
#   'Host': 'httpbin.org',
#   'User-Agent': 'python-requests/2.23.0',
#   'X-Amzn-Trace-Id': 'Root=1-5ee8c674-3be6b400fd0a0cbb6f3a1213'},
#  'json': None,
#  'origin': '1.162.97.8',
#  'url': 'http://httpbin.org/post'}

# %% [markdown]
# ## 作業目標
#
# * 比較一下範例檔案中的「r.text」與「json.loads(r.text)」讀出來的內容有什麼差異
# * 自行尋找一個合適的 API 接口做練習，並且查看其回傳內容
#     * https://cat-fact.herokuapp.com/facts (來源：https://alexwohlbruck.github.io/cat-facts/)
#     * http://odata.wra.gov.tw/v4/RealtimeWaterLevel (來源：https://data.gov.tw/dataset/25768)
