# %% [markdown]
# # Ettoday 網路爬蟲實作練習
#
#
# * 能夠利用 Request + BeatifulSour 撰寫爬蟲，並存放到合適的資料結構

# %% [markdown]
# ## 作業目標
#
# 根據範例：
#
# 1. 取出今天所有的新聞
# 2. 取出現在時間兩小時內的新聞
# 3. 根據範例，取出三天前下午三點到五點的新聞

# %%
import requests
import time
import pandas as pd
from bs4 import BeautifulSoup
from datetime import datetime, timedelta
from selenium import webdriver
# 選擇選單
from selenium.webdriver.support.ui import Select

# %%
# 擷取網址
url = "https://www.ettoday.net/news/news-list.htm"

r = requests.get(url)
soup = BeautifulSoup(r.text, "lxml")

# %% [markdown]
# ## 1. 取出今天所有的新聞

# %%
#  設置日期
#  timedelta(1) 預設為1日
date_time = datetime.now() - timedelta(1)
date_time = date_time.strftime("%Y/%m/%d")
print("取得昨天時間：", date_time)

# 利用 selenium 持續執行下滑的動作，直到取得「昨天時間」的新聞，表示今天的已經取得完畢

browser = webdriver.Chrome(executable_path='chromedriver')
browser.get(url)

while True:
    # scrollTo 的設置是指 total scroll 的長度，而不是單次 scroll 的長度，這會影響擷取的次數
    browser.execute_script("window.scrollTo(0, 100000);")
    time.sleep(2)
    html_source = browser.page_source
    soup = BeautifulSoup(html_source, "lxml")
    print(soup.find_all(class_="part_list_2")[-1].find_all("h3")[-1].find(class_="date").text)
    if date_time in soup.find_all(class_="part_list_2")[-1].find_all("h3")[-1].find(class_="date").text:
        print("===STOP===")
        break
        
html_source = browser.page_source
soup = BeautifulSoup(html_source, "lxml")

for d in soup.find(class_="part_list_2").find_all("h3"):
    if date_time in d.find(class_="date").text:
        break
    print(d.find(class_="date").text, d.find_all("a")[-1].text)

# 資料整理
news = []

for d in soup.find(class_="part_list_2").find_all("h3"):
    if date_time in d.find(class_="date").text:
        break
    news.append({
        '時間': d.find(class_="date").text,
        '標題': d.find_all("a")[-1].text
    })

# pd.DataFrame(news)

browser.close()
# Out:
# 取得昨天時間： 2020/06/14
# 2020/06/15 09:47
# 2020/06/15 09:12
# 2020/06/15 09:00
# 2020/06/15 08:32
# 2020/06/15 07:56
# 2020/06/15 07:20
# 2020/06/15 06:03
# 2020/06/15 02:07
# 2020/06/15 00:13
# 2020/06/14 23:21
# ===STOP===
# 2020/06/15 11:45 光寶股東會通過：每股配息3.2元　現金殖利率6.3%！EPS年增18%「創3年來新高」
# 2020/06/15 11:44 陳其邁躺著選？　名嘴點出「兩大挑戰」：他應該緊張！高雄市民很累
# 2020/06/15 11:44 大甲媽祝壽大典改奉天宮廟內舉行　拜豬公求智慧毛只剩1頭
# 2020/06/15 11:44 改個錯字「網路誹謗罪」成立！　菲律賓《時代》年度風雲人物面臨7年監禁
# 2020/06/15 11:43 北京「4天62確診」開始究責　豐台區副區長、疫情爆發市場總經理全下台！
# 2020/06/15 11:41 iPhone 12系列生產模具曝光！間接說明 5 項新機傳聞
# 2020/06/15 11:41 找室內設計師來估價…卻要先付「5000元出圖費」！她傻了：業界都這樣？
# 2020/06/15 11:39 把家寫成「厝」　閩南語漢字專家：自己在詛咒自己
# 2020/06/15 11:37 黃捷回嗆：鳳山的「鳳」不是那麼好寫　喊「罷免要先想好理由」
# 2020/06/15 11:37 雞排妹「3個月菜鳥」股票爽撈50萬！曾被交易員勸退...她堅持：26歲人生解鎖
# 2020/06/15 11:35 「砸出球棒印」！路怒族汐止塞車火氣大　超車不成怒砸前車後擋風玻璃
# 2020/06/15 11:35 「這條街最醜房」！夫妻倆買下「灌入時尚元素」　超美落地窗秒成當地網紅景點
# 2020/06/15 11:34 沈榮津接行政院副院長？　陳其邁大讚：史上最強歐吉桑
# 2020/06/15 11:33 悠遊付祭優惠　共享機車會員1280定期票打7折
# 2020/06/15 11:33 北京疫情傳播鏈已跨省！河北一家四人染疫「6歲女童去過幼稚園」
# 2020/06/15 11:32 單驥／廣明光電滅頂賠償案：科技戰後的法律戰
# 2020/06/15 11:31 鳳凰旅行社通過配息1.25元股利　加強金馬澎離島行程穩營運
# 2020/06/15 11:31 輔選高雄市長？　侯友宜：市政優先　有餘力一定全力幫忙
# 2020/06/15 11:31 熱水器突然爆炸！爸媽幫17個月嬰兒洗澡　3人全身95%嚴重燙傷
# 2020/06/15 11:31 武漢5月新房成交量破萬　楊光華：數據「忽高忽低」不正常
# 2020/06/15 11:30 最有錢／鮮肉分析師岔賭！半月績效比輸贏　除權息節稅
# 2020/06/15 11:29 疫情衝擊英國4月經濟　按月降幅達20.4％史上最慘
# 2020/06/15 11:27 書櫃快爆炸、衣櫥關不上？4原則解決收納災難...「衣服直放」更省空間
# 2020/06/15 11:26 女兒盡孝快遞「大麻油」回台...差點害到病母！　驗出這成分不起訴
# 2020/06/15 11:25 香港迪士尼18日重新開放　入園須先預約、配戴口罩
# 2020/06/15 11:25 給說法／檢察官不能當辯護律師嗎
# 2020/06/15 11:24 老師批作文負能量！　小五女衝出教室「翻欄杆墜樓亡」...學校過30分才通知
# 2020/06/15 11:23 林志潔／聯電美光案啟示　美國共謀犯罪與法人刑事責任
# 2020/06/15 11:20 iPhone 12最新模具圖曝光！　蘋果全系列商品可望走回經典設計
# 2020/06/15 11:20 敷泥膜必注意3件事！乾了才洗是大忌　做錯會讓肌膚更糟
# 2020/06/15 11:18 要簽名忘帶筆...王嘉爾暖回「我在這等你」！　結果簽名遭8萬轉賣
# 2020/06/15 11:16 運動家白人強打後悔沒響應麥克斯韋單膝禮　決定勇敢為反歧視發聲
# 2020/06/15 11:15 外籍學生何時能返台？台大公衛提「2建議」：免疫護照證明未染疫
# 2020/06/15 11:15 老鳥教練叫菜鳥帶學員最後1堂課潛水竟溺斃！3教練判刑
# 2020/06/15 11:13 健保自費醫材設天花板「效益不大」　蔡壁如：政務官要為自己政策辯護
# 2020/06/15 11:13 外交部捍衛釣魚台主權　那霸辦事處2度去電警告石垣市長
# 2020/06/15 11:11 BLACKPINK釋出最新回歸照！LISA變紅髮　Jennie、Rosé雙髮色曝光
# 2020/06/15 11:08 3大主題遊程曝光！走進森林裡的綠建築、享受酒廠微醺時光
# 2020/06/15 11:08 北韓強硬嗆動武南韓　分析曝「威逼內幕」：空飄傳單只是藉口！
# 2020/06/15 11:07 連續8天手作仙奶凍買1送1！八月堂誠品信義店新開張　還有黑糖蕨餅限定可頌
# 2020/06/15 11:06 慕谷慕魚沒開放！「遊客改去翡翠谷」花蓮人曬垃圾照　大嘆：在考慮封閉了
# 2020/06/15 11:06 蔣萬安要求陳其邁速辦釣魚台釣魚大賽　「我會第一個報名」
# 2020/06/15 11:04 帶看瞬增2成！社交距離拉大  加速3地「墅民」時代來臨
# 2020/06/15 11:03 役男花16萬找「僵直性脊椎炎患者」代打體檢　還介紹給同梯…2人提前退伍
# 2020/06/15 11:01 邱吉爾雕像遭噴「種族主義」示威者嗆拆除　強生火大：不該抹去歷史
# 2020/06/15 11:00 日妞最愛的隨身整髮三寶　「小尺寸」放入包中剛剛好！
# 2020/06/15 10:59 敬老卡加碼延期公佈　黃珊珊：不希望北市有加碼之亂
# 2020/06/15 10:59 8歲等等數學題總是寫「2個答案」　親吐原因讓孫儷傻眼了！
# 2020/06/15 10:58 韓職／韓華老鷹中止18連敗　球團向球迷道歉將召回下放10人
# 2020/06/15 10:58 北京一日再增59人陽性！海淀「玉泉東市場」也緊急關閉
# 2020/06/15 10:57 2020再傳噩耗！前湖人球星加馬克過世　他是林書豪「尼克17號」前輩之一
# 2020/06/15 10:55 國民黨要蔡英文站出來捍衛釣魚台　陳玉珍擬安排「登島」考察
# 2020/06/15 10:54 走進童話小木屋！苗栗秘境咖啡民宿　絕美空中走廊超浪漫
# 2020/06/15 10:52 坐公車就能玩翻台中IG打卡熱點！沿台灣大道來趟夏日輕旅行
# 2020/06/15 10:51 當視障朋友的眼！　中壽首推「點字版保單」說明
# 2020/06/15 10:50 《天堂2：革命》更新　 加入全新領地、飾品覺醒系統和電音派對
# 2020/06/15 10:49 《決勝時刻M》新主題「輻射危機」刺激上線　生存模式大改版！
# 2020/06/15 10:48 恆春0負評民宿老闆砸車…脫口「就是工人的貨車」！女護爸悲吼：該讓你糟蹋？
# 2020/06/15 10:47 診所開窗就看到小禎！　李進良驚「陰魂不散」離婚卡8個月曝近況
# 2020/06/15 10:47 誰的566萬？「3公斤黃金」遺留火車上　瑞士再等5年盼失主領回
# 2020/06/15 10:47 台北國際ACG博覽會7月底開跑　電玩電競動漫一同展出
# 2020/06/15 10:45 幫女兒蘇巧慧跟蔡英文喬中常委？　蘇貞昌親口回應了
# 2020/06/15 10:44 歐陽靖曝「譚艾珍42年前細肩擠胸照」　驚嘆：尺度好大！
# 2020/06/15 10:43 苑裡靈修會暗夜大火爆炸聲不斷　百坪神壇燒光！5人驚險逃出
# 2020/06/15 10:42 在家染出沙龍級秀髮「洗護」是關鍵！護色洗髮精＋髮膜雙加持　健康光澤髮絲超撩人
# 2020/06/15 10:40 「抗菌」乾洗手標示不清稱醫療效能　消基會抽查12款無產品許可證字號
# 2020/06/15 10:39 華航公布7月航線增班計畫！倫敦改降希斯洛機場　6/16起恢復提供熱餐
# 2020/06/15 10:39 虐妻17年！刺殺不成開瓦斯喊「報警就跳樓」　她崩潰訴離竟遭嗆：自己選的
# 2020/06/15 10:38 友訊市場派要擦亮金字招牌　李中旺：組「夢幻組合網」邁向全世界
# 2020/06/15 10:37 愛兒麗產後護理之家台中館6月正式開幕
# 2020/06/15 10:37 漏掛安全繫繩！農場女工滑倒「跌進葵花籽桶」　掙扎仍遭活埋死
# 2020/06/15 10:36 史上最大宗3500公斤「毒喵喵」曝光！市價逾70億...總統蔡英文都來看了
# 2020/06/15 10:36 家有「小型森林」當空氣清淨機　Briiv用苔蘚淨化家中大氣
# 2020/06/15 10:34 埔里杷城排洪道加裝「電眼」蒐證　往河道亂丟垃圾「最高罰6000元」
# 2020/06/15 10:33 宜蘭天空出現罕見「火彩虹」　奇景太美！網：好想沖洗出來裱掛
# 2020/06/15 10:33 趙麗穎1歲兒子正面照被拍！　深夜帶想想外出聚餐…畫面曝光網友卻怒了
# 2020/06/15 10:32 快訊／防疫新生活　北市宣布：6月20日校園全面開放
# 2020/06/15 10:29 快訊／北商大墜樓學生曾多次心理諮商　「掛鼻胃管」不適校方輔導仍傳憾事
# 2020/06/15 10:27 自費醫材設天花板挨轟喊卡　蘇貞昌：政策推出應該要讓團隊知道
# 2020/06/15 10:22 選前談民調挨罰50萬　唐湘龍不服：才講20秒！不符合比例
# 2020/06/15 10:21 釣大魚請女友全家吃！一夥人嗨吃下肚…被告知是「非食用魚類」有毒
# 2020/06/15 10:20 屏東男站騎樓遭撞死！　肇逃女駕駛找民代陪同投案：不知撞到人
# 2020/06/15 10:19 女童重寫秘密問卷...隋棠看了心痛沉默！「長期遭叔姪性侵」不堪故事惹鼻酸
# 2020/06/15 10:18 「成人、兒童」5大MIT品牌口罩網購再開搶　時間、限購看這裡
# 2020/06/15 10:18 林書豪曾要暴龍「寄冠軍戒」給他遭拒　憶奪冠：我的人生是巨大奇蹟
# 2020/06/15 10:18 「3年前分析墜樓」網友引用爆許崑源被丟下　高大成捲陰謀論：勿誤導視聽
# 2020/06/15 10:18 晚上睡不好…白天累爆！秒測「你有睡眠債」嗎　18分以上＝危險性嗜睡
# 2020/06/15 10:15 影／北京8區淪陷！4天新增79例「1人重症」　50歲男發病6天後就診
# 2020/06/15 10:11 第一支手機病毒16歲了！誕生於2004年6月15日　靠發送加值服務簡訊撈錢
# 2020/06/15 10:11 紐約州重啟「投訴暴增2.5萬件」　州長：違規次數過多…將直接暫停重啟！
# 2020/06/15 10:10 回家驚見「超壯客人」在門外避陽！她哭笑不得…網羨：高級食材上門了
# 2020/06/15 10:07 軍機擾台》亓樂義／三海較勁：美中印太博弈新趨向
# 2020/06/15 10:05 高雄女騎車自摔...半小時後有重要考試！　警車一路鳴笛載她去
# 2020/06/15 10:04 TWICE安可舞台…背景男聲「她們真的很不會唱」網吵翻！　SBS雙畫面揭真相
# 2020/06/15 10:04 北京新一波疫情傳染源揭秘！ 　流行病學專家：有2種可能
# 2020/06/15 10:02 「藍白合作」無果…將親自出戰？　蔡壁如：最後一刻再來決定
# 2020/06/15 10:02 台中「299吃到飽」強勢回歸！驚見高單價食材　客吐不吃千元buffet原因
# 2020/06/15 10:00 友訊經營權變天！市場派大勝拿下6席董事　公司派僅獲3席
# 2020/06/15 10:00 好樂迪通過配發4.4元現金股利　宜蘭展新門店落實全台佈局
# 2020/06/15 10:00 遭杏仁哥譏諷「嫖妓議員」高喊罷免！　陳致中不後悔：相信罷韓讓高雄更好
# 2020/06/15 10:00 蘿莉塔爆曖昧無尊「爸媽都在問」：聘金先拿來！　還原穿內褲視訊經過
# 2020/06/15 10:00 料多、沙茶味濃郁！台中銷魂爆炒花枝麵　滿滿蛤蜊湯只要30元
# 2020/06/15 09:59 「黑臉扮泰人」宣傳新品⋯挨轟沒水準、低級！日出茶太道歉了
# 2020/06/15 09:56 全球789萬例染疫、43萬人病逝　歐洲露曙光…馬克宏宣布法國重大解封
# 2020/06/15 09:54 沈榮津接任副閣揆？　蘇貞昌笑：現在想這個會對陳其邁不好意思
# 2020/06/15 09:54 大甲媽祖出巡牽紅線　超市「紅利5倍送」再抽百枚媽祖過火加持金牌
# 2020/06/15 09:53 果嶺最性感選手示範「巨乳夾桿」　拍裸照反網路霸凌
# 2020/06/15 09:50 尿有泡泡不等於是「腎虧」！　 是不是腎臟病要看泡泡持續多久！
# 2020/06/15 09:48 蘆洲「首購天堂」出列！當地人稱最強商圈捷運宅　入手價700萬起
# 2020/06/15 09:47 恆春防風林瀕絕椰子蟹又遭網纏　海巡救援野放獲重生
# 2020/06/15 09:46 聊生子話題…伊能靜突變臉「拉婆婆離開客廳」：別搭話了！　高情商1舉動顧慮到所有人
# 2020/06/15 09:38 宮崎駿藏在動畫的10大人生哲理：生活壞到一定程度就會好起來，因為它無法更壞
# 2020/06/15 09:33 不肖業者假借宣導及檢修名義行不法推銷　台南市消防局籲請民眾注意提防
# 2020/06/15 09:30 10盎司牛肋排400元有找　WILDWOOD餐廳點波士頓龍蝦專屬加購價
# 2020/06/15 09:28 花蓮最大免費玩水點！知卡宣森林親水公園7/18開放　從720度滑水道急速落下
# 2020/06/15 09:25 日本「佛系歌手」邀全球60名僧侶線上誦經　開唱10秒淨化網友
# 2020/06/15 09:22 影／北京新冠肺炎又增36確診！　孫春蘭坦言：疫情擴散風險很高
# 2020/06/15 09:17 炎炎夏日喝再多水都覺渴？　小心中暑及熱衰竭悄悄上門來
# 2020/06/15 09:16 新台幣開盤貶值1.8分　以29.780元開出
# 2020/06/15 09:12 杜紫宸揭名嘴「特權待遇」　周玉蔻、黃光芹等10人都上榜
# 2020/06/15 09:11 摺疊iPhone要來了！爆料者間接證實蘋果已在開發中
# 2020/06/15 09:08 快訊／台北商業大學「女大生墜樓」！無呼吸心跳　送醫搶救中
# 2020/06/15 09:07 台股早盤上漲24點！聯電侵權美光挨罰1億　今開盤跌近2%
# 2020/06/15 09:05 原廠不做，我自己動手畫！國外設計師釋出超帥氣三菱4000GT概念圖
# 2020/06/15 09:03 金材昱詭笑殺戮、曹政奭狂飆害死人！「最渣」斯文敗類男演員Top5
# 2020/06/15 09:03 頭痛、眼痛吃止痛藥好不了？　醫：按摩有利改善
# 2020/06/15 09:02 捕蛇男與「5米巨蟒」扭打激戰！他遭狠咬噴血　驚險畫面曝光
# 2020/06/15 09:01 暗房中來2次！工程師買春睡醒出事　警一查「茉茉」真實身分：他會崩潰
# 2020/06/15 09:01 獨／從一盆多肉說起！仙人掌植物園乘載三代回憶「故事超暖」
# 2020/06/15 09:00 卡地亞譜寫Santos Dumont經典傳奇　限量款鐫刻飛行器重現冒險夢
# 2020/06/15 08:54 女偶像收到影片點開嚇瘋！　睡著「私生飯站身後唱生日歌」恐怖慶生
# 2020/06/15 08:51 破解不肖搬家公司9大加價手法　專家提自保方案避吃虧
# 2020/06/15 08:46 NBA球隊前進迪士尼前2天每天篩檢　623開始實施
# 2020/06/15 08:44 欠債百萬殺人棄屍苗栗山區！2嫌供詞有出入　遭檢方聲押
# 2020/06/15 08:42 影／27歲非裔男驗屍結果出爐！　「背部中2彈」臟器毀大出血：死因列凶殺
# 2020/06/15 08:40 癌復發後苦等8個月！余苑綺「今天動開肝手術」　堅強告白：為了寶貝們我一定會好
# 2020/06/15 08:39 家族聚會吃4450元霸王餐！兩桌人分批落跑　佛心老闆娘還幫留面子
# 2020/06/15 08:38 大陸第4億萬富豪「自家遭劫持」　何享健別墅外「對峙現場曝光」...5嫌犯落網
# 2020/06/15 08:35 厄文號召反種族歧視「罷賽」　NBA體諒願與工會溝通
# 2020/06/15 08:32 瘋電影／愛美獎行動　抗議後產生史上首位黑人世界小姐
# 2020/06/15 08:30 惡狼網路獵童…甜交小六女友「老公親一個」！無助家長泣訴：快被逼瘋
# 2020/06/15 08:18 金與正放話動武！南韓軍方高度戒備　青瓦台：情況十分嚴重
# 2020/06/15 08:11 繼承Kobe至少6億美元財產　眾多球星追求凡妮莎
# 2020/06/15 08:09 Ean部落閣／宜蘭兩天這樣玩！老街藏「虹吸煮茶」　體驗立槳再泡湯
# 2020/06/15 08:03 亞特蘭大再傳槍擊！歹徒大街上開槍「打帶跑」　至少2死5傷
# 2020/06/15 08:03 特斯拉Model 3改用「磷酸鋰鐵電池」售價有望降低，車重卻增加
# 2020/06/15 08:03 魚刺哽到喉嚨吞飯、喝醋都NG　第一時間這樣處理才是正解
# 2020/06/15 08:01 18歲就出道只當過藝人！　40歲小嫻零遮掩「墾丁餐廳打工換宿」
# 2020/06/15 07:57 台記者稱「3萬飛彈難登陸」　解放軍退役中將嗆「目標早編號」：最小毀損達成！
# 2020/06/15 07:56 星貴婦買房團現蹤信義區！　歐陽娜娜家霸氣「狂掃12戶豪宅」團購拚殺價
# 2020/06/15 07:51 愛妻「恩愛照」外流！警夫怒告神展開　前同事家搜出7顆硬碟
# 2020/06/15 07:49 吳夢夢為拍SOD「狂鏟10kg」成果照出爐！　全身只穿XL白內褲…巨胸形狀掉出來了
# 2020/06/15 07:48 子瑜被出賣「崩壞私照」曝光！張大嘴打哈欠狂翻白眼　最美女神反差超萌
# 2020/06/15 07:43 香港富商傳掀「資金出走潮」　憂《國安法》動搖金融中心地位
# 2020/06/15 07:36 高雄學校爆「鼻病毒群聚感染」　名醫憂心：台灣個人防護已鬆懈
# 2020/06/15 07:33 小馬曝辛龍轉變：比較放心了！　群組聊天陪伴「我們都在」
# 2020/06/15 07:32 小禎合體胡瓜主持《地球人》1個月改版　認觀眾兩極：有代溝！
# 2020/06/15 07:31 三倍券官網本周六上線　滙豐、渣打首刷回饋上看1500元最吸睛
# 2020/06/15 07:26 洗窗平台7樓下墜「橫的變垂直」！2工人卡土城高空8分鐘　住戶：砰好大一聲
# 2020/06/15 07:20 新堀江悼許崑源看板P上5字秒變地獄哏　臉書遮蔽理由網友全歪樓
# 2020/06/15 07:10 夏天一定要會的涼爽穿搭！5樣「必備單品」直接化身型男
# 2020/06/15 07:08 畢業新鮮人看過來！　就業補貼3萬元今上路、懶人包一次看
# 2020/06/15 07:05 女星澆樹摔傷「右腳裹成象腿」！　往下看「9000元拖鞋」才是亮點
# 2020/06/15 07:03 鐵質之王「紅肉火龍果」　2種人不宜吃太多
# 2020/06/15 07:00 唐綺陽運勢／水逆又來了！金牛想有桃花「掌握1關鍵」　2星座好好睡一覺吧
# 2020/06/15 07:00 台灣內需服務業服務業冰火兩極　「這產業」大幅成長！
# 2020/06/15 06:38 川普西點軍校16秒走下坡「有困難」影瘋傳　怒推文：是坡度太陡太滑
# 2020/06/15 06:31 陳其邁鬆口談補選：高雄需要重開機　和韓國瑜還是朋友
# 2020/06/15 06:13 今防午後雷雨！下波「滯留鋒面+西南氣流」大變天時間　吳德榮說話了
# 2020/06/15 06:03 《復仇者聯盟4》邋遢索爾Q版玩偶！肥肚加鬍渣神還原　陪你一起在家耍宅
# 2020/06/15 05:56 土耳其規模5.8地震1死18傷！　2觀測塔倒塌「壓死」警衛
# 2020/06/15 05:56 影／疫情防控3缺失！　北京豐台區副區長、批發市場總經理被免職
# 2020/06/15 05:53 「美的集團」創始人驚傳遭挾持！　兒子逃出別墅渡河報警
# 2020/06/15 03:13 台北3大夜市PK排行出爐！「話題王」狂刷6倍討論度　骰子牛爆紅
# 2020/06/15 02:23 蔡其昌辦千人戶外後疫情音樂會　國台交高美濕地浪漫登場
# 2020/06/15 02:21 花蓮籌備龍舟競渡緊鑼密鼓　徐榛蔚為龍舟開光點睛
# 2020/06/15 02:19 大園種西瓜體驗　為什麼大部分剛長出的西瓜都被摘除？
# 2020/06/15 02:18 搭機捷來賞鳥免費用　桃園野鳥學會6/20舉辦「探險賞鳥趣」
# 2020/06/15 02:08 搶救228烈士湯德章故居行動成功達標！　8千多人讚助募得2多千萬元
# 2020/06/15 02:07 土城15年老字號「行李箱賣600元」！員工淚曝辛酸　霸氣老闆：虧錢也要發薪
# 2020/06/15 01:54 新堀江掛上「追悼許崑源」！白色看板被酸爆　攤商曝背後原因
# 2020/06/15 01:28 「吃半熟豬肉」18歲男體內爬滿寄生蟲　頭痛到爆炸求醫…照出超驚悚影像
# 2020/06/15 00:50 斯亞賣網拍「發文抱怨物流」被砲轟！　直播氣哭了…委屈罵：誰來體諒賣家
# 2020/06/15 00:48 唐鳳遭爆「監視Line群組對話」！韓粉社團瘋傳…網看帳號傻眼：裝睡的人叫不醒
# 2020/06/15 00:44 高雄成立「終結致中站」！韓粉網路拚連署：這次換我們反中
# 2020/06/15 00:34 因疫情已停賽3個月　大馬女神發長文細數好多的第一次
# 2020/06/15 00:19 北京陷二波疫情…楊紫爆「隔離14天劇組停拍」　本尊曬鐵證照打臉
# 2020/06/15 00:15 墾丁民宿「深夜開趴」！爬屋頂嘶吼唱歌、放鞭炮　他住隔壁崩潰：根本災難
# 2020/06/15 00:13 企甲／銘傳平台鋼大雷雨宣布停賽　台中德比戰FUTURO3比2台體
# 2020/06/15 00:13 退休教授高喊「槍斃蔡英文」　王定宇：必須嚴辦，最重關2年
# 2020/06/15 00:03 「梅雨眼妝」必備3大防水單品　暴雨爆汗也能hold住
# 2020/06/15 00:01 3大關鍵因素　沈榮津接替陳其邁掌副閣揆呼聲最高
# 2020/06/15 00:00 雷／《若是一個人》完結倒數　謝瓊煖醫院「交代一生」網全看哭了

# %% [markdown]
# ## 2. 取出現在時間兩小時內的新聞

# %%
two_hour_date_time = datetime.now() - timedelta(hours = 2)

for d in soup.find(class_="part_list_2").find_all("h3"):
    if datetime.strptime(d.find(class_="date").text, "%Y/%m/%d %H:%M") < two_hour_date_time:
        break
    news.append({
        '時間': d.find(class_="date").text,
        '標題': d.find_all("a")[-1].text
    })
pd.DataFrame(news)
# Out:
#                    時間                                           標題
# 0    2020/06/15 11:45  光寶股東會通過：每股配息3.2元　現金殖利率6.3%！EPS年增18%「創3年來新高」
# 1    2020/06/15 11:44              陳其邁躺著選？　名嘴點出「兩大挑戰」：他應該緊張！高雄市民很累
# 2    2020/06/15 11:44                  大甲媽祝壽大典改奉天宮廟內舉行　拜豬公求智慧毛只剩1頭
# 3    2020/06/15 11:44           改個錯字「網路誹謗罪」成立！　菲律賓《時代》年度風雲人物面臨7年監禁
# 4    2020/06/15 11:43          北京「4天62確診」開始究責　豐台區副區長、疫情爆發市場總經理全下台！
# ..                ...                                          ...
# 298  2020/06/15 09:54              大甲媽祖出巡牽紅線　超市「紅利5倍送」再抽百枚媽祖過火加持金牌
# 299  2020/06/15 09:53                     果嶺最性感選手示範「巨乳夾桿」　拍裸照反網路霸凌
# 300  2020/06/15 09:50               尿有泡泡不等於是「腎虧」！　 是不是腎臟病要看泡泡持續多久！
# 301  2020/06/15 09:48              蘆洲「首購天堂」出列！當地人稱最強商圈捷運宅　入手價700萬起
# 302  2020/06/15 09:47                     恆春防風林瀕絕椰子蟹又遭網纏　海巡救援野放獲重生
#
# [303 rows x 2 columns]

# %% [markdown]
# ## 3. 根據範例，取出三天前下午三點到五點的新聞

# %%
browser = webdriver.Chrome(executable_path='chromedriver')

browser.get("https://www.ettoday.net/news/news-list.htm")

three_days_date_time = datetime.now() - timedelta(3)
print('取得三天前的時間：', three_days_date_time.strftime("%Y/%m/%d"))

three_days_month = three_days_date_time.strftime("%-m")
three_days_day = three_days_date_time.strftime("%-d")

print('取得三天前的月：',three_days_month)
print('取得三天前的日：',three_days_day)

# strptime () 函數根據指定的格式把一個時間字符串解析為時間元組。
# strftime () 函數接收以時間元組，並返回以可讀字符串表示的當地時間，格式由參數 format 決定。

three_days_15_clock = datetime.strptime(three_days_date_time.strftime("%Y/%m/%d") + " 15", '%Y/%m/%d %H')
three_days_17_clock = datetime.strptime(three_days_date_time.strftime("%Y/%m/%d") + " 17", '%Y/%m/%d %H')

print('取得三天前下午三點：',three_days_15_clock)
print('取得三天前下午五點：',three_days_17_clock)
# Out:
# 取得三天前的時間： 2020/06/12
# 取得三天前的月： 6
# 取得三天前的日： 12
# 取得三天前下午三點： 2020-06-12 15:00:00
# 取得三天前下午五點： 2020-06-12 17:00:00

# %%
selM = Select(browser.find_element_by_id("selM"))
selM.select_by_value(three_days_month)
selD = Select(browser.find_element_by_id("selD"))
selD.select_by_value(three_days_day)
browser.find_element_by_id("button").click()

# %%
while True:
    browser.execute_script("window.scrollTo(0, 100000);")
    time.sleep(2)
    html_source = browser.page_source
    soup = BeautifulSoup(html_source, "lxml")
    new_date = soup.find_all(class_="part_list_2")[-1].find_all("h3")[-1].find(class_="date").text
    print(new_date)
    if datetime.strptime(new_date, "%Y/%m/%d %H:%M") < three_days_15_clock:
        print('====STOP====')
        break
# Out:
# 2020/06/12 19:39
# 2020/06/12 19:25
# 2020/06/12 19:05
# 2020/06/12 18:58
# 2020/06/12 18:51
# 2020/06/12 18:45
# 2020/06/12 18:32
# 2020/06/12 18:23
# 2020/06/12 18:17
# 2020/06/12 18:06
# 2020/06/12 17:57
# 2020/06/12 17:50
# 2020/06/12 17:44
# 2020/06/12 17:36
# 2020/06/12 17:30
# 2020/06/12 17:18
# 2020/06/12 17:07
# 2020/06/12 17:01
# 2020/06/12 16:55
# 2020/06/12 16:37
# 2020/06/12 16:25
# 2020/06/12 16:20
# 2020/06/12 16:10
# 2020/06/12 16:05
# 2020/06/12 15:56
# 2020/06/12 15:48
# 2020/06/12 15:40
# 2020/06/12 15:31
# 2020/06/12 15:25
# 2020/06/12 15:15
# 2020/06/12 15:07
# 2020/06/12 15:01
# 2020/06/12 14:56
# ====STOP====

# %%
news = []
for d in soup.find(class_="part_list_2").find_all("h3"):
    # 比兩小時前早的話就結束
    if datetime.strptime(d.find(class_="date").text, "%Y/%m/%d %H:%M") < three_days_15_clock:
        print("===stop===")
        break
    if datetime.strptime(d.find(class_="date").text, "%Y/%m/%d %H:%M") < three_days_17_clock:
        news.append({
            '時間': d.find(class_="date").text,
            '標題': d.find_all("a")[-1].text
        })
        
pd.DataFrame(news)
# Out:
# ===stop===
#                    時間                                     標題
# 0    2020/06/12 16:58           台南北門釣客「踩破水泥橋」落水　民眾急拋繩力抗急流救一命
# 1    2020/06/12 16:57  蘭嶼出現Uber Eats外送機車　鄉民大樂「終於有了！」答案讓人跌破眼鏡
# 2    2020/06/12 16:57               尋找你的甲蟲王　《小森生活》全新甲蟲對戰系統上線
# 3    2020/06/12 16:56      「Galaxy Tab S7」渲染圖流出！　傳機身側面新增指紋感應
# 4    2020/06/12 16:55   印尼看護才剛繳清仲介費卻罹罕病！台人暖募40萬...助母妹來台捐骨髓救命
# ..                ...                                    ...
# 134  2020/06/12 15:01        「小突兔主題餐廳與限定店」快閃三創　超可愛奶酪＋杯墊手刀衝一波
# 135  2020/06/12 15:01     《最後生還者二部曲》上市前無雷評測　跟著艾莉踏上「胃絞痛」的復仇之旅
# 136  2020/06/12 15:00       快訊／台南警「追落跑嫌疑犯」！路口撞上機車　25歲騎士重傷搶救中
# 137  2020/06/12 15:00              川普讚國民兵鎮暴是美麗風景線　衝進人群像刀切奶油！
# 138  2020/06/12 15:00           必點咖哩公仔麵！隱身台南巷弄的港式餐館　戶外座位超有港味
#
# [139 rows x 2 columns]

# %%
browser.close()
